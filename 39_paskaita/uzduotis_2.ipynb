# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# Jūsų užduotis nagrinėti realius duomenis:
#
# šalia šio failo rasite pateiktus du duomenų rinkinius: gyvensena2016.csv gyvensensena2020.csv
#
# Jūsų užduoties tikslas pasiimti duomenis (nuskaityti failą, visus veiksmus atlikite vienam failui, tik po to kitam). Nustatyti, kuriuos stulpelius norite nagrinėti. Pasirinktu būdu sukurti klasterius. Po to atlikite tą patį su sekančiu failu ir palyginkite pasiskirstymą.

# %%
data_2016 = pd.read_csv('Gyvensena2016.csv')

selected_features = data_2016[['fizine_veikla_be_pamoku', 'pusryciai_dd', 'pusryciai_savaitgaliai', 'vaisiai', 'darzoves', 'gyvenimas_tabakas', 'gyvenimas_elektronines_cigaretes', 'gyvenimas_alkoholis', 'gyvenimas_apsvaigimas', 'metai_apsvaigimas',  'gyvenimas_kanapes','gyvenimas_kiti_narkotikai', 'demesys_sveikai_gyvensenai', 'demesys_fiziniam_aktyvumui', 'demesys_mitybai', 'demesys_rukymo_prevencijai', 'demesys_alkoholio_prevencijai', 'demesys_narkotiku_prevencijai', 'patycios_is_kitu', 'patirtos_patycios', 'fizines_bausmes', 'dantys', 'nelaimingi_atsitikimai', 'atsvaitai', 'saugos_dirzai', 'sveikata']]

agg_cluster = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

agg_cluster.fit(selected_features)

linked = linkage(selected_features, 'ward')
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchinis klasterizavimas')
plt.xlabel('Klasterių skaičius')
plt.ylabel('Atstumas')
plt.show()
